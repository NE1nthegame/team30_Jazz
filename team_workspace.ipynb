# %% [markdown]
# # 🎷 Рабочее пространство команды Jazz
#
# ## Инструкция для первого запуска (один раз)
# 1. Создайте свой Personal Access Token на GitHub (Settings → Developer settings → Tokens → repo)
# 2. Замените `ВАШ_ТОКЕН` в ячейке ниже на свой токен
# 3. Выполните все ячейки по порядку (Runtime → Run all)

# %%
# КЛОНИРОВАНИЕ РЕПОЗИТОРИЯ (замените токен, логин и название проекта)
# !git clone https://ВАШ_ТОКЕН@github.com/NE1nthegame/jazz_team_project.git

# %%
# ПЕРЕХОД В ПАПКУ ПРОЕКТА
# %cd jazz_team_project

# %%
# НАСТРОЙКА GIT (укажите свои имя и почту)
# !git config --global user.email "ваша_почта@example.com"
# !git config --global user.name "Ваше Имя"

# %%
# ПОЛУЧИТЬ ПОСЛЕДНИЕ ОБНОВЛЕНИЯ ОТ КОМАНДЫ
# !git pull origin main

# %% [markdown]
# ## 📝 Теперь пишите ваш код в следующих ячейках

# %%
# Пример: импортируем библиотеки
import pandas as pd
import numpy as np
print("Рабочая среда готова!")

# %%
# Здесь можно написать ваш основной код
def analyze_data(data):
    return data.describe()

# Создаем пример данных
df = pd.DataFrame({'x': np.random.randn(100), 'y': np.random.randn(100)})
print(analyze_data(df))

# %% [markdown]
# ## 💾 ОТПРАВИТЬ ИЗМЕНЕНИЯ НА GITHUB
#
# Выполните следующие ячейки, когда захотите сохранить свой код в репозиторий для команды

# %%
# Добавить все изменённые файлы
# !git add .

# %%
# Создать коммит (измените сообщение на своё)
# !git commit -m "Обновил анализ данных"

# %%
# Отправить на GitHub
# !git push origin main
